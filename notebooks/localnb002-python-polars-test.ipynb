# %%
input_file = "../input/amex-default-prediction/train_data.csv"

# %%
import polars as pl

# %%
df = pl.read_csv(input_file)

# %%
df.head()
# Out:
# shape: (5, 190)
# ┌───────────┬────────┬────────┬───────┬─────┬───────┬───────┬───────┬───────┐
# │ customer_ ┆ S_2    ┆ P_2    ┆ D_39  ┆ ... ┆ D_142 ┆ D_143 ┆ D_144 ┆ D_145 │
# │ ID        ┆ ---    ┆ ---    ┆ ---   ┆     ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ ---       ┆ str    ┆ f64    ┆ f64   ┆     ┆ str   ┆ f64   ┆ f64   ┆ f64   │
# │ str       ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ╞═══════════╪════════╪════════╪═══════╪═════╪═══════╪═══════╪═══════╪═══════╡
# │ 0000099d6 ┆ 2017-0 ┆ 0.9384 ┆ 0.001 ┆ ... ┆ null  ┆ 0.000 ┆ 0.000 ┆ 0.002 │
# │ bd597052c ┆ 3-09   ┆ 69     ┆ 733   ┆     ┆       ┆ 569   ┆ 6     ┆ 674   │
# │ dcda90ffa ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# │ bf565...  ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 0000099d6 ┆ 2017-0 ┆ 0.9366 ┆ 0.005 ┆ ... ┆ null  ┆ 0.009 ┆ 0.005 ┆ 0.009 │
# ...

# %%
df.tail()
# Out:
# shape: (5, 190)
# ┌───────────┬────────┬────────┬───────┬─────┬───────┬───────┬───────┬───────┐
# │ customer_ ┆ S_2    ┆ P_2    ┆ D_39  ┆ ... ┆ D_142 ┆ D_143 ┆ D_144 ┆ D_145 │
# │ ID        ┆ ---    ┆ ---    ┆ ---   ┆     ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ ---       ┆ str    ┆ f64    ┆ f64   ┆     ┆ str   ┆ f64   ┆ f64   ┆ f64   │
# │ str       ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ╞═══════════╪════════╪════════╪═══════╪═════╪═══════╪═══════╪═══════╪═══════╡
# │ fffff1d38 ┆ 2017-1 ┆ 0.9793 ┆ 0.416 ┆ ... ┆ null  ┆ 0.000 ┆ 0.001 ┆ 0.002 │
# │ b785cef84 ┆ 1-05   ┆ 32     ┆ 013   ┆     ┆       ┆ 905   ┆ 498   ┆ 774   │
# │ adeace64f ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# │ 8f83d...  ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ fffff1d38 ┆ 2017-1 ┆ 0.9849 ┆ 0.296 ┆ ... ┆ null  ┆ 0.002 ┆ 0.008 ┆ 0.008 │
# ...

# %%
type(df)
# Out:
# polars.internals.frame.DataFrame

# %%
tmp = (df.groupby('customer_ID')
       .agg(
           pl.col('P_2').apply(lambda r: r)#.alias('P_2_2')
       ))
type(tmp)
# Out:
# polars.internals.frame.DataFrame

# %%
tmp
# Out:
# shape: (458913, 2)
# ┌─────────────────────────────────────┬─────────────────────────────────────┐
# │ customer_ID                         ┆ P_2                                 │
# │ ---                                 ┆ ---                                 │
# │ str                                 ┆ list[f64]                           │
# ╞═════════════════════════════════════╪═════════════════════════════════════╡
# │ 5c2062dea303ebe861443f79a0c957bb... ┆ [0.842181, 0.792765, ... 0.81265... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 1af1a47309691d6b8ba4442d673dad6d... ┆ [0.803372, 0.797083, ... 0.79365... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 88a786a58b11db5d38d5ba347d386ab4... ┆ [0.978943, 0.975921, ... 1.00356... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ cd3b422e484337d8fbd5dd2c435f15f1... ┆ [0.744231, 0.697768, ... 0.68769... │
# ...

# %%
tmp = tmp.sort('customer_ID')

# %%
res = []
for i in range(len(tmp)):
    res.append(tmp[i, 'P_2_2'])

# %%
pl.concat(res)
# Out:
# shape: (5531451,)
# Series: 'P_2_2' [f64]
# [
# 	0.643997
# 	0.606016
# 	0.609551
# 	0.602317
# 	0.608275
# 	0.6023
# 	0.612973
# 	0.610911
# 	0.605762
# 	0.560986
# 	0.561947
# 	0.365215
# 	...
# 	0.755633
# 	0.874852
# 	0.861774
# 	0.818535
# 	0.880721
# 	0.829609
# 	0.869
# 	0.9173
# 	0.938571
# 	0.868007
# 	0.945181
# 	0.943527
# ]

# %%
cid = df['customer_ID'][0]
print(cid)
# Out:
# 0000099d6bd597052cdcda90ffabf56573fe9d7c79be5fbac11a8ed792feb62a

# %%
tmp['customer_ID'][0]
# Out:
# 'a02e6314854b98bf1df207087bee390deab0d9353def7959f2b10386b27c1fcf'

# %%
tmp
# Out:
# shape: (458913, 2)
# ┌─────────────────────────────────────┬─────────────────────────────────────┐
# │ customer_ID                         ┆ P_2_2                               │
# │ ---                                 ┆ ---                                 │
# │ str                                 ┆ list[f64]                           │
# ╞═════════════════════════════════════╪═════════════════════════════════════╡
# │ a02e6314854b98bf1df207087bee390d... ┆ [0.643997, 0.606016, ... 0.35939... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ d3d0ed3a3abd35cb230572e90f874dd4... ┆ [0.844626, 0.899062, ... 0.86142... │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ 7c811c3adae12cdf90e46115255c8aec... ┆ [0.270061, 0.315183, ... 0.3205]    │
# ├╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌╌┤
# │ f901c20681b4e7ef6f3a664ca23aa928... ┆ [0.410743, 0.4193, ... 0.416347]    │
# ...

# %%
tmp.shape
# Out:
# (458913, 2)

# %%
tmp['P_2_2'].reshape((-1,))
# Out:
# shape: (5531451,)
# Series: 'P_2_2' [f64]
# [
# 	0.643997
# 	0.606016
# 	0.609551
# 	0.602317
# 	0.608275
# 	0.6023
# 	0.612973
# 	0.610911
# 	0.605762
# 	0.560986
# 	0.561947
# 	0.365215
# 	...
# 	0.755633
# 	0.874852
# 	0.861774
# 	0.818535
# 	0.880721
# 	0.829609
# 	0.869
# 	0.9173
# 	0.938571
# 	0.868007
# 	0.945181
# 	0.943527
# ]

# %%
df['P_2']
# Out:
# shape: (5531451,)
# Series: 'P_2' [f64]
# [
# 	0.938469
# 	0.936665
# 	0.9541
# 	0.960384
# 	0.947248
# 	0.945964
# 	0.940705
# 	0.914767
# 	0.950845
# 	0.8685
# 	0.909811
# 	0.937349
# 	...
# 	1.0
# 	0.994954
# 	1.005768
# 	0.965709
# 	0.968892
# 	0.9737
# 	0.979511
# 	0.979332
# 	0.984907
# 	0.983019
# 	0.969861
# 	0.982175
# ]

# %%
df['D_39'] = df['D_39']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-4b16a64a758b> in <module>
# ----> 1 df['D_39'] = df['D_39']
#
# TypeError: 'DataFrame' object does not support item assignment

# %%
df.with_columns([
    pl.col("D_39")==0.938469
])
# Out:
# shape: (5531451, 190)
# ┌───────────┬────────┬────────┬───────┬─────┬───────┬───────┬───────┬───────┐
# │ customer_ ┆ S_2    ┆ P_2    ┆ D_39  ┆ ... ┆ D_142 ┆ D_143 ┆ D_144 ┆ D_145 │
# │ ID        ┆ ---    ┆ ---    ┆ ---   ┆     ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ ---       ┆ str    ┆ f64    ┆ bool  ┆     ┆ str   ┆ f64   ┆ f64   ┆ f64   │
# │ str       ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ╞═══════════╪════════╪════════╪═══════╪═════╪═══════╪═══════╪═══════╪═══════╡
# │ 0000099d6 ┆ 2017-0 ┆ 0.9384 ┆ false ┆ ... ┆ null  ┆ 0.000 ┆ 0.000 ┆ 0.002 │
# │ bd597052c ┆ 3-09   ┆ 69     ┆       ┆     ┆       ┆ 569   ┆ 6     ┆ 674   │
# │ dcda90ffa ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# │ bf565...  ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 0000099d6 ┆ 2017-0 ┆ 0.9366 ┆ false ┆ ... ┆ null  ┆ 0.009 ┆ 0.005 ┆ 0.009 │
# ...

# %%
from scipy.interpolate import CubicSpline
import numpy as np

def cubic_spline(y):
    x = np.arange(len(y))
    cs = CubicSpline(x, y)
    y = cs(x)
    return y
    

def cs_imputator(df, categorical_cols, verbose=False):
    for col in df.columns:
        if (col not in categorical_cols) & (col != 'customer_ID'):
            
            if verbose:
                print(f'Null proportion of calumn {col} before imputation: {df[col].is_null().mean()}')
            
            # rows = df.groupby('customer_ID').apply(lambda r: r[col])
            # for i,y in enumerate(rows):
            #     x = np.arrange(len(y))
            #     cs = CubicSpline(x, y)
            #     rows[i] = cs(x)
            # df[col] = rows.values.reshape(-1, 1)
            
            #### PL
            df = (df.groupby('customer_ID')
                   .agg(
                       pl.col(col).apply(lambda r: cubic_spline(r))
                   ))
            
            # for cid in df['customer_ID'].unique().values:
            #     y = df.loc[df['customer_ID'] == cid, col].values
            #     x = np.arrange(len(y))
            #     cs = CubicSpline(x, y)
            #     y = cs(x)
            #     df['customer_ID'] = np.where(df['customer_ID'] == cid, y, df['customer_ID'])
            
            
            if verbose:
                print(f'Null proportion of calumn {col} after imputation: {df[col].is_null().mean()}')
                print()
                #print(f'Type of df: {type(df)}')
    
    return df

# %%
CATS = ['B_30', 'B_38', 'D_114', 'D_116', 'D_117', 'D_120', 'D_126', 'D_66', 'D_68']
# OFFSETS = [2,1,2,2,3,2,3,2,2] #2 minus minimal value in full train csv
# # then 0 will be padding, 1 will be NAN, 2,3,4,etc will be values
# for c,s in zip(CATS,OFFSETS):
#     train[c] = train[c] + s
#     train[c] = train[c].fillna(1).astype('int8')
CATS += ['D_63','D_64']

# %%
df.with_columns([
    df['customer_ID'].apply(lambda x: int(x[-16:],16) ).cast(pl.Int64, strict=False)
])
# Out:
# shape: (5531451, 190)
# ┌───────────┬────────┬────────┬───────┬─────┬───────┬───────┬───────┬───────┐
# │ customer_ ┆ S_2    ┆ P_2    ┆ D_39  ┆ ... ┆ D_142 ┆ D_143 ┆ D_144 ┆ D_145 │
# │ ID        ┆ ---    ┆ ---    ┆ ---   ┆     ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ ---       ┆ str    ┆ f64    ┆ f64   ┆     ┆ str   ┆ f64   ┆ f64   ┆ f64   │
# │ i64       ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ╞═══════════╪════════╪════════╪═══════╪═════╪═══════╪═══════╪═══════╪═══════╡
# │ null      ┆ 2017-0 ┆ 0.9384 ┆ 0.001 ┆ ... ┆ null  ┆ 0.000 ┆ 0.000 ┆ 0.002 │
# │           ┆ 3-09   ┆ 69     ┆ 733   ┆     ┆       ┆ 569   ┆ 6     ┆ 674   │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ null      ┆ 2017-0 ┆ 0.9366 ┆ 0.005 ┆ ... ┆ null  ┆ 0.009 ┆ 0.005 ┆ 0.009 │
# │           ┆ 4-07   ┆ 65     ┆ 775   ┆     ┆       ┆ 576   ┆ 492   ┆ 217   │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# ...

# %%
df
# Out:
# shape: (5531451, 190)
# ┌───────────┬────────┬────────┬───────┬─────┬───────┬───────┬───────┬───────┐
# │ customer_ ┆ S_2    ┆ P_2    ┆ D_39  ┆ ... ┆ D_142 ┆ D_143 ┆ D_144 ┆ D_145 │
# │ ID        ┆ ---    ┆ ---    ┆ ---   ┆     ┆ ---   ┆ ---   ┆ ---   ┆ ---   │
# │ ---       ┆ str    ┆ f64    ┆ f64   ┆     ┆ str   ┆ f64   ┆ f64   ┆ f64   │
# │ str       ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ╞═══════════╪════════╪════════╪═══════╪═════╪═══════╪═══════╪═══════╪═══════╡
# │ 0000099d6 ┆ 2017-0 ┆ 0.9384 ┆ 0.001 ┆ ... ┆ null  ┆ 0.000 ┆ 0.000 ┆ 0.002 │
# │ bd597052c ┆ 3-09   ┆ 69     ┆ 733   ┆     ┆       ┆ 569   ┆ 6     ┆ 674   │
# │ dcda90ffa ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# │ bf565...  ┆        ┆        ┆       ┆     ┆       ┆       ┆       ┆       │
# ├╌╌╌╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┼╌╌╌╌╌╌╌┤
# │ 0000099d6 ┆ 2017-0 ┆ 0.9366 ┆ 0.005 ┆ ... ┆ null  ┆ 0.009 ┆ 0.005 ┆ 0.009 │
# ...

# %%
df_imp = cs_imputator(df, CATS, verbose=True)
# Out:
# Null proportion of calumn S_2 before imputation: 0.0
# ---------------------------------------------------------------------------
# ComputeError                              Traceback (most recent call last)
# <ipython-input-111-056c647c55e9> in <module>
# ----> 1 df_imp = cs_imputator(df, CATS, verbose=True)
#
# <ipython-input-102-c53a331473ea> in cs_imputator(df, categorical_cols, verbose)
#      24
#      25             #### PL
# ---> 26             df = (df.groupby('customer_ID')
#      27                    .agg(
#      28                        pl.col(col).apply(lambda r: cubic_spline(r))
#
# ~/miniconda3/envs/rustaconda/lib/python3.8/site-packages/polars/internals/frame.py in agg(self, aggs)
#    6194         """
#    6195         df = (
# -> 6196             wrap_df(self._df)
#    6197             .lazy()
#    6198             .groupby(self.by, maintain_order=self.maintain_order)
#
# ...

# %%
df.dtypes
# Out:
# [polars.datatypes.Utf8,
#  polars.datatypes.Utf8,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Utf8,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
#  polars.datatypes.Float64,
# ...

# %%
ndf = df.to_numpy()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-114-b7e51cf16bf4> in <module>
# ----> 1 ndf = df.to_numpy()
#
# ~/miniconda3/envs/rustaconda/lib/python3.8/site-packages/polars/internals/frame.py in to_numpy(self)
#    1397         if out is None:
#    1398             return np.vstack(
# -> 1399                 [self.to_series(i).to_numpy() for i in range(self.width)]
#    1400             ).T
#    1401         else:
#
# ~/miniconda3/envs/rustaconda/lib/python3.8/site-packages/polars/internals/frame.py in <listcomp>(.0)
#    1397         if out is None:
#    1398             return np.vstack(
# -> 1399                 [self.to_series(i).to_numpy() for i in range(self.width)]
#    1400             ).T
#    1401         else:
#
# ~/miniconda3/envs/rustaconda/lib/python3.8/site-packages/polars/internals/series.py in to_numpy(self, zero_copy_only, *args, **kwargs)
# ...
