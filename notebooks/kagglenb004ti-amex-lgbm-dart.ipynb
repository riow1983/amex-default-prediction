# %%
comp_name = "amex-default-prediction"
nb_name = 'kagglenb004ti-amex-lgbm-dart'

import sys
import os
from pathlib import Path

if "google.colab" in sys.modules:
    from google.colab import drive
    drive.mount("/content/drive")
    base = f"/content/drive/MyDrive/colab_notebooks/kaggle/{comp_name}/notebooks"
    # %cd {base}

KAGGLE_ENV = True if 'KAGGLE_URL_BASE' in set(os.environ.keys()) else False
INPUT_DIR = Path('../input/')

if KAGGLE_ENV:
    OUTPUT_DIR = Path('')
else:
    # !mkdir ../input/{nb_name}
    OUTPUT_DIR = INPUT_DIR / nb_name
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/colab_notebooks/kaggle/amex-default-prediction/notebooks
# mkdir: cannot create directory ‘../input/kagglenb004ti-amex-lgbm-dart’: File exists

# %%
# THRES = 0.999999
# THRES = 0.999998
THRES = 0.9

# %% [markdown]
# # Comments:
#
# This is an improvement of my baseline, you can find it here: https://www.kaggle.com/code/ragnar123/amex-lgbm-dart-cv-0-7963
#
# The main difference between this solution and previous one is that we add new features and do seed blend to boost LB. Single 5 kfold model using seed 42 achieve an out of folds CV of 0.7977 and a public leaderboard of 0.799. If we use seed blend (train three different models using seed 42, 52, 62 and then average predictions) the LB boost niceley.
#
# The main features that boost CV are the following:
#
# * The difference between last value and the lag1
# * The difference between last value and the average (this features gives a nice boost)
#
# This feature engineer is done on all the last columns, so we actually add a lot of features, this model used 1368 features.
#
# I uploaded test predictions to avoid running training and inference
#
# Next Steps:
#
# * Could try feature selection, maybe a lot of the feature are just noise, actually I perform permutation importance and I reduce the amount of features to 1000 app and the CV was almost the same. Maybe there is a better feature selection technique that can boost performance.
#
# * Could try different models, maybe some neural network with the same features or a subset of the features and then blend with LGBM can work, in my experience blending tree models and neural network works great because they are very diverse so the boost is nice
#
# * Could try more feature engineering, maybe we can create more features that extract the hidden signal of the dataset, actually I would first work on this option and really try to capture all the signal that the dataset has.

# %% [markdown]
# # Preprocessing

# %%
# ====================================================
# Library
# ====================================================
import gc
import warnings
warnings.filterwarnings('ignore')
import scipy as sp
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
import itertools

# ====================================================
# Get the difference
# ====================================================
def get_difference(data, num_features):
    df1 = []
    customer_ids = []
    for customer_id, df in tqdm(data.groupby(['customer_ID'])):
        # Get the differences
        diff_df1 = df[num_features].diff(1).iloc[[-1]].values.astype(np.float32)
        # Append to lists
        df1.append(diff_df1)
        customer_ids.append(customer_id)
    # Concatenate
    df1 = np.concatenate(df1, axis = 0)
    # Transform to dataframe
    df1 = pd.DataFrame(df1, columns = [col + '_diff1' for col in df[num_features].columns])
    # Add customer id
    df1['customer_ID'] = customer_ids
    return df1

# ====================================================
# Read & preprocess data and save it to disk
# ====================================================
def read_preprocess_data():
    train = pd.read_parquet(INPUT_DIR / 'amex-data-integer-dtypes-parquet-format/train.parquet')
    
    #### RIOW
    print('train.shape before filtering: ', train.shape)
    train_adv = pd.read_parquet(INPUT_DIR / 'kagglenb003-adversarial-validation/train_adv_valid.parquet')
    train_adv = train_adv[['customer_ID', 'private']]
    train = pd.merge(train, train_adv, how='inner', on='customer_ID')
    del train_adv
    gc.collect()
    # train = train[train['private'] >= THRES]
    train = train[train['private'] < THRES]
    train.drop('private', axis=1, inplace=True)
    print('train.shape after filtering: ', train.shape)
    #### RIOWRIOW

    features = train.drop(['customer_ID', 'S_2'], axis = 1).columns.to_list()
    cat_features = [
        "B_30",
        "B_38",
        "D_114",
        "D_116",
        "D_117",
        "D_120",
        "D_126",
        "D_63",
        "D_64",
        "D_66",
        "D_68",
    ]
    num_features = [col for col in features if col not in cat_features]
    print('Starting training feature engineer...')
    train_num_agg = train.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    train_num_agg.columns = ['_'.join(x) for x in train_num_agg.columns]
    train_num_agg.reset_index(inplace = True)
    train_cat_agg = train.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    train_cat_agg.columns = ['_'.join(x) for x in train_cat_agg.columns]
    train_cat_agg.reset_index(inplace = True)
    train_labels = pd.read_csv(INPUT_DIR / 'amex-default-prediction/train_labels.csv')
    # Transform float64 columns to float32
    cols = list(train_num_agg.dtypes[train_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        train_num_agg[col] = train_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(train_cat_agg.dtypes[train_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        train_cat_agg[col] = train_cat_agg[col].astype(np.int32)
    # Get the difference
    train_diff = get_difference(train, num_features)
    train = train_num_agg.merge(train_cat_agg, how = 'inner', on = 'customer_ID').merge(train_diff, how = 'inner', on = 'customer_ID').merge(train_labels, how = 'inner', on = 'customer_ID')
    del train_num_agg, train_cat_agg, train_diff
    gc.collect()


    test = pd.read_parquet(INPUT_DIR / 'amex-data-integer-dtypes-parquet-format/test.parquet')
    print('Starting test feature engineer...')
    test_num_agg = test.groupby("customer_ID")[num_features].agg(['mean', 'std', 'min', 'max', 'last'])
    test_num_agg.columns = ['_'.join(x) for x in test_num_agg.columns]
    test_num_agg.reset_index(inplace = True)
    test_cat_agg = test.groupby("customer_ID")[cat_features].agg(['count', 'last', 'nunique'])
    test_cat_agg.columns = ['_'.join(x) for x in test_cat_agg.columns]
    test_cat_agg.reset_index(inplace = True)
    # Transform float64 columns to float32
    cols = list(test_num_agg.dtypes[test_num_agg.dtypes == 'float64'].index)
    for col in tqdm(cols):
        test_num_agg[col] = test_num_agg[col].astype(np.float32)
    # Transform int64 columns to int32
    cols = list(test_cat_agg.dtypes[test_cat_agg.dtypes == 'int64'].index)
    for col in tqdm(cols):
        test_cat_agg[col] = test_cat_agg[col].astype(np.int32)
    # Get the difference
    test_diff = get_difference(test, num_features)
    test = test_num_agg.merge(test_cat_agg, how = 'inner', on = 'customer_ID').merge(test_diff, how = 'inner', on = 'customer_ID')
    del test_num_agg, test_cat_agg, test_diff
    gc.collect()
    # Save files to disk
    train.to_parquet(OUTPUT_DIR / f'train_fe_adv{THRES}.parquet')
    test.to_parquet(OUTPUT_DIR / 'test_fe.parquet')

# %%
# Read & Preprocess Data

# THRES: >=0.9
# train.shape before filtering:  (5531451, 190)
# train.shape after filtering:  (5218818, 191)

# THRES: >=0.999999
# train.shape before filtering:  (5531451, 190)
# train.shape after filtering:  (2439599, 190)

# THRES: >=0.999998
# train.shape before filtering:  (5531451, 190)
# train.shape after filtering:  (3487223, 190)

# THRES: <0.9
# train.shape before filtering:  (5531451, 190)
# train.shape after filtering:  (312633, 190)

read_preprocess_data()
# Out:
# train.shape before filtering:  (5531451, 190)
# train.shape after filtering:  (312633, 190)
# Starting training feature engineer...
#   0%|          | 0/261 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/26762 [00:00<?, ?it/s]
# Starting test feature engineer...
#   0%|          | 0/261 [00:00<?, ?it/s]
#   0%|          | 0/22 [00:00<?, ?it/s]
#   0%|          | 0/924621 [00:00<?, ?it/s]

# %% [markdown]
# # Training & Inference

# %%
# ====================================================
# Library
# ====================================================
import os
import gc
import warnings
warnings.filterwarnings('ignore')
import random
import scipy as sp
import numpy as np
import pandas as pd
import joblib
import itertools
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
from tqdm.auto import tqdm
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.preprocessing import LabelEncoder
import lightgbm as lgb
from itertools import combinations

# ====================================================
# Configurations
# ====================================================
class CFG:
    #input_dir = '/content/data/'
    seed = 42
    n_folds = 5
    target = 'target'
    boosting_type = 'dart'
    metric = 'binary_logloss'

# ====================================================
# Seed everything
# ====================================================
def seed_everything(seed):
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    CFG.seed = seed

# ====================================================
# Read data
# ====================================================
def read_data():
    train = pd.read_parquet(OUTPUT_DIR / f'train_fe_adv{THRES}.parquet')
    test = pd.read_parquet(OUTPUT_DIR / 'test_fe.parquet')
    return train, test

# ====================================================
# Amex metric
# ====================================================
def amex_metric(y_true, y_pred):
    labels = np.transpose(np.array([y_true, y_pred]))
    labels = labels[labels[:, 1].argsort()[::-1]]
    weights = np.where(labels[:,0]==0, 20, 1)
    cut_vals = labels[np.cumsum(weights) <= int(0.04 * np.sum(weights))]
    top_four = np.sum(cut_vals[:,0]) / np.sum(labels[:,0])
    gini = [0,0]
    for i in [1,0]:
        labels = np.transpose(np.array([y_true, y_pred]))
        labels = labels[labels[:, i].argsort()[::-1]]
        weight = np.where(labels[:,0]==0, 20, 1)
        weight_random = np.cumsum(weight / np.sum(weight))
        total_pos = np.sum(labels[:, 0] *  weight)
        cum_pos_found = np.cumsum(labels[:, 0] * weight)
        lorentz = cum_pos_found / total_pos
        gini[i] = np.sum((lorentz - weight_random) * weight)
    return 0.5 * (gini[1]/gini[0] + top_four)

# ====================================================
# LGBM amex metric
# ====================================================
def lgb_amex_metric(y_pred, y_true):
    y_true = y_true.get_label()
    return 'amex_metric', amex_metric(y_true, y_pred), True

# ====================================================
# Train & Evaluate
# ====================================================
def train_and_evaluate(train, test):
    # Label encode categorical features
    cat_features = [
        "B_30",
        "B_38",
        "D_114",
        "D_116",
        "D_117",
        "D_120",
        "D_126",
        "D_63",
        "D_64",
        "D_66",
        "D_68"
    ]
    cat_features = [f"{cf}_last" for cf in cat_features]
    for cat_col in cat_features:
        encoder = LabelEncoder()
        train[cat_col] = encoder.fit_transform(train[cat_col])
        test[cat_col] = encoder.transform(test[cat_col])
    # Round last float features to 2 decimal place
    num_cols = list(train.dtypes[(train.dtypes == 'float32') | (train.dtypes == 'float64')].index)
    num_cols = [col for col in num_cols if 'last' in col]
    for col in num_cols:
        train[col + '_round2'] = train[col].round(2)
        test[col + '_round2'] = test[col].round(2)
    # Get the difference between last and mean
    num_cols = [col for col in train.columns if 'last' in col]
    num_cols = [col[:-5] for col in num_cols if 'round' not in col]
    for col in num_cols:
        try:
            train[f'{col}_last_mean_diff'] = train[f'{col}_last'] - train[f'{col}_mean']
            test[f'{col}_last_mean_diff'] = test[f'{col}_last'] - test[f'{col}_mean']
        except:
            pass
    # Transform float64 and float32 to float16
    num_cols = list(train.dtypes[(train.dtypes == 'float32') | (train.dtypes == 'float64')].index)
    for col in tqdm(num_cols):
        train[col] = train[col].astype(np.float16)
        test[col] = test[col].astype(np.float16)
    # Get feature list
    features = [col for col in train.columns if col not in ['customer_ID', CFG.target]]
    params = {
        'objective': 'binary',
        'metric': CFG.metric,
        'boosting': CFG.boosting_type,
        'seed': CFG.seed,
        'num_leaves': 100,
        'learning_rate': 0.01,
        'feature_fraction': 0.20,
        'bagging_freq': 10,
        'bagging_fraction': 0.50,
        'n_jobs': -1,
        'lambda_l2': 2,
        'min_data_in_leaf': 40,
        'device': 'gpu',
        'gpu_platform_id': 0,
        'gpu_device_id': 0
        }
    # Create a numpy array to store test predictions
    test_predictions = np.zeros(len(test))
    # Create a numpy array to store out of folds predictions
    oof_predictions = np.zeros(len(train))
    kfold = StratifiedKFold(n_splits = CFG.n_folds, shuffle = True, random_state = CFG.seed)
    for fold, (trn_ind, val_ind) in enumerate(kfold.split(train, train[CFG.target])):
        print(' ')
        print('-'*50)
        print(f'Training fold {fold} with {len(features)} features...')
        x_train, x_val = train[features].iloc[trn_ind], train[features].iloc[val_ind]
        y_train, y_val = train[CFG.target].iloc[trn_ind], train[CFG.target].iloc[val_ind]
        lgb_train = lgb.Dataset(x_train, y_train, categorical_feature = cat_features)
        lgb_valid = lgb.Dataset(x_val, y_val, categorical_feature = cat_features)
        model = lgb.train(
            params = params,
            train_set = lgb_train,
            num_boost_round = 10500,
            valid_sets = [lgb_train, lgb_valid],
            early_stopping_rounds = 1500,
            verbose_eval = 500,
            feval = lgb_amex_metric
            )
        # Save best model
        joblib.dump(model, OUTPUT_DIR / f'lgbm_{CFG.boosting_type}_fold{fold}_seed{CFG.seed}_adv{THRES}.pkl')
        # Predict validation
        val_pred = model.predict(x_val)
        # Add to out of folds array
        oof_predictions[val_ind] = val_pred
        # Predict the test set
        test_pred = model.predict(test[features])
        test_predictions += test_pred / CFG.n_folds
        # Compute fold metric
        score = amex_metric(y_val, val_pred)
        print(f'Our fold {fold} CV score is {score}')
        del x_train, x_val, y_train, y_val, lgb_train, lgb_valid
        gc.collect()
    # Compute out of folds metric
    score = amex_metric(train[CFG.target], oof_predictions)
    print(f'Our out of folds CV score is {score}')
    # Create a dataframe to store out of folds predictions
    oof_df = pd.DataFrame({'customer_ID': train['customer_ID'], 'target': train[CFG.target], 'prediction': oof_predictions})
    oof_df.to_csv(OUTPUT_DIR / f'oof_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}_adv{THRES}.csv', index = False)
    # Create a dataframe to store test prediction
    test_df = pd.DataFrame({'customer_ID': test['customer_ID'], 'prediction': test_predictions})
    test_df.to_csv(OUTPUT_DIR / f'test_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{CFG.seed}_adv{THRES}.csv', index = False)

# %%
# train, test = read_data()

# seeds = [42, 1192, 2022]
# for seed in seeds:
#     seed_everything(seed)
#     train_and_evaluate(train, test)
# Out:
#   0%|          | 0/1080 [00:00<?, ?it/s]
#
# --------------------------------------------------
# Training fold 0 with 1365 features...
# [500]	training's binary_logloss: 0.334536	training's amex_metric: 0.781721	valid_1's binary_logloss: 0.338276	valid_1's amex_metric: 0.769764
# [1000]	training's binary_logloss: 0.243046	training's amex_metric: 0.798292	valid_1's binary_logloss: 0.251414	valid_1's amex_metric: 0.780825
# [1500]	training's binary_logloss: 0.218637	training's amex_metric: 0.812457	valid_1's binary_logloss: 0.231539	valid_1's amex_metric: 0.786467
# [2000]	training's binary_logloss: 0.204989	training's amex_metric: 0.825414	valid_1's binary_logloss: 0.223045	valid_1's amex_metric: 0.79059
# [2500]	training's binary_logloss: 0.197981	training's amex_metric: 0.835812	valid_1's binary_logloss: 0.220291	valid_1's amex_metric: 0.792441
# [3000]	training's binary_logloss: 0.190926	training's amex_metric: 0.845837	valid_1's binary_logloss: 0.21811	valid_1's amex_metric: 0.794376
# [3500]	training's binary_logloss: 0.184401	training's amex_metric: 0.856043	valid_1's binary_logloss: 0.216633	valid_1's amex_metric: 0.795434
# [4000]	training's binary_logloss: 0.178636	training's amex_metric: 0.865917	valid_1's binary_logloss: 0.215798	valid_1's amex_metric: 0.795736
# [4500]	training's binary_logloss: 0.173011	training's amex_metric: 0.875305	valid_1's binary_logloss: 0.215025	valid_1's amex_metric: 0.796642
# [5000]	training's binary_logloss: 0.167432	training's amex_metric: 0.884789	valid_1's binary_logloss: 0.21446	valid_1's amex_metric: 0.796991
# [5500]	training's binary_logloss: 0.162479	training's amex_metric: 0.893482	valid_1's binary_logloss: 0.214099	valid_1's amex_metric: 0.797137
# [6000]	training's binary_logloss: 0.158233	training's amex_metric: 0.901812	valid_1's binary_logloss: 0.213925	valid_1's amex_metric: 0.797326
# [6500]	training's binary_logloss: 0.153781	training's amex_metric: 0.908321	valid_1's binary_logloss: 0.213666	valid_1's amex_metric: 0.797745
# [7000]	training's binary_logloss: 0.148637	training's amex_metric: 0.91649	valid_1's binary_logloss: 0.213441	valid_1's amex_metric: 0.798083
# [7500]	training's binary_logloss: 0.143773	training's amex_metric: 0.924456	valid_1's binary_logloss: 0.213331	valid_1's amex_metric: 0.797726
# [8000]	training's binary_logloss: 0.139474	training's amex_metric: 0.93177	valid_1's binary_logloss: 0.213344	valid_1's amex_metric: 0.797847
# [8500]	training's binary_logloss: 0.135749	training's amex_metric: 0.938245	valid_1's binary_logloss: 0.213302	valid_1's amex_metric: 0.798128
# [9000]	training's binary_logloss: 0.131551	training's amex_metric: 0.944448	valid_1's binary_logloss: 0.213211	valid_1's amex_metric: 0.798197
# [9500]	training's binary_logloss: 0.127793	training's amex_metric: 0.949846	valid_1's binary_logloss: 0.213214	valid_1's amex_metric: 0.798238
# [10000]	training's binary_logloss: 0.124114	training's amex_metric: 0.955309	valid_1's binary_logloss: 0.21317	valid_1's amex_metric: 0.798324
# [10500]	training's binary_logloss: 0.120895	training's amex_metric: 0.959539	valid_1's binary_logloss: 0.213226	valid_1's amex_metric: 0.797615
# Our fold 0 CV score is 0.7976152376970185
#
# --------------------------------------------------
# Training fold 1 with 1365 features...
# [500]	training's binary_logloss: 0.334558	training's amex_metric: 0.782685	valid_1's binary_logloss: 0.337863	valid_1's amex_metric: 0.764451
# [1000]	training's binary_logloss: 0.24309	training's amex_metric: 0.799559	valid_1's binary_logloss: 0.250715	valid_1's amex_metric: 0.774878
# [1500]	training's binary_logloss: 0.218765	training's amex_metric: 0.813331	valid_1's binary_logloss: 0.230834	valid_1's amex_metric: 0.781176
# [2000]	training's binary_logloss: 0.205016	training's amex_metric: 0.826607	valid_1's binary_logloss: 0.222536	valid_1's amex_metric: 0.785716
# [2500]	training's binary_logloss: 0.197954	training's amex_metric: 0.837072	valid_1's binary_logloss: 0.219875	valid_1's amex_metric: 0.788098
# [3000]	training's binary_logloss: 0.190937	training's amex_metric: 0.846452	valid_1's binary_logloss: 0.217878	valid_1's amex_metric: 0.789662
# [3500]	training's binary_logloss: 0.184416	training's amex_metric: 0.856626	valid_1's binary_logloss: 0.216585	valid_1's amex_metric: 0.790347
# [4000]	training's binary_logloss: 0.17864	training's amex_metric: 0.866822	valid_1's binary_logloss: 0.215798	valid_1's amex_metric: 0.791382
# [4500]	training's binary_logloss: 0.173049	training's amex_metric: 0.875921	valid_1's binary_logloss: 0.215099	valid_1's amex_metric: 0.792309
# [5000]	training's binary_logloss: 0.167498	training's amex_metric: 0.885385	valid_1's binary_logloss: 0.214633	valid_1's amex_metric: 0.792451
# [5500]	training's binary_logloss: 0.162555	training's amex_metric: 0.893882	valid_1's binary_logloss: 0.214335	valid_1's amex_metric: 0.792887
# [6000]	training's binary_logloss: 0.158278	training's amex_metric: 0.901895	valid_1's binary_logloss: 0.21419	valid_1's amex_metric: 0.792841
# [6500]	training's binary_logloss: 0.153801	training's amex_metric: 0.909124	valid_1's binary_logloss: 0.214027	valid_1's amex_metric: 0.792622
# [7000]	training's binary_logloss: 0.148668	training's amex_metric: 0.916787	valid_1's binary_logloss: 0.213805	valid_1's amex_metric: 0.793152
# [7500]	training's binary_logloss: 0.143758	training's amex_metric: 0.925037	valid_1's binary_logloss: 0.213666	valid_1's amex_metric: 0.793395
# [8000]	training's binary_logloss: 0.139448	training's amex_metric: 0.93167	valid_1's binary_logloss: 0.213632	valid_1's amex_metric: 0.793246
# [8500]	training's binary_logloss: 0.135745	training's amex_metric: 0.93794	valid_1's binary_logloss: 0.213589	valid_1's amex_metric: 0.793037
# [9000]	training's binary_logloss: 0.131545	training's amex_metric: 0.944366	valid_1's binary_logloss: 0.213531	valid_1's amex_metric: 0.793821
# [9500]	training's binary_logloss: 0.127776	training's amex_metric: 0.949574	valid_1's binary_logloss: 0.213552	valid_1's amex_metric: 0.794225
# [10000]	training's binary_logloss: 0.124127	training's amex_metric: 0.954763	valid_1's binary_logloss: 0.213532	valid_1's amex_metric: 0.794841
# [10500]	training's binary_logloss: 0.12094	training's amex_metric: 0.958874	valid_1's binary_logloss: 0.213535	valid_1's amex_metric: 0.794714
# Our fold 1 CV score is 0.7947141173032984
#
# --------------------------------------------------
# Training fold 2 with 1365 features...
# [500]	training's binary_logloss: 0.334639	training's amex_metric: 0.780956	valid_1's binary_logloss: 0.338149	valid_1's amex_metric: 0.769171
# [1000]	training's binary_logloss: 0.243192	training's amex_metric: 0.798279	valid_1's binary_logloss: 0.251087	valid_1's amex_metric: 0.779107
# [1500]	training's binary_logloss: 0.218856	training's amex_metric: 0.812226	valid_1's binary_logloss: 0.231078	valid_1's amex_metric: 0.785424
# [2000]	training's binary_logloss: 0.20511	training's amex_metric: 0.825504	valid_1's binary_logloss: 0.222619	valid_1's amex_metric: 0.790302
# [2500]	training's binary_logloss: 0.198092	training's amex_metric: 0.83605	valid_1's binary_logloss: 0.219933	valid_1's amex_metric: 0.792612
# [3000]	training's binary_logloss: 0.191004	training's amex_metric: 0.846078	valid_1's binary_logloss: 0.217737	valid_1's amex_metric: 0.794397
# [3500]	training's binary_logloss: 0.1845	training's amex_metric: 0.855988	valid_1's binary_logloss: 0.216425	valid_1's amex_metric: 0.794678
# [4000]	training's binary_logloss: 0.178729	training's amex_metric: 0.865912	valid_1's binary_logloss: 0.215588	valid_1's amex_metric: 0.795882
# [4500]	training's binary_logloss: 0.173083	training's amex_metric: 0.875617	valid_1's binary_logloss: 0.214914	valid_1's amex_metric: 0.795963
# [5000]	training's binary_logloss: 0.167528	training's amex_metric: 0.884908	valid_1's binary_logloss: 0.214358	valid_1's amex_metric: 0.796117
# [5500]	training's binary_logloss: 0.162584	training's amex_metric: 0.893111	valid_1's binary_logloss: 0.214046	valid_1's amex_metric: 0.797022
# [6000]	training's binary_logloss: 0.158313	training's amex_metric: 0.900723	valid_1's binary_logloss: 0.213875	valid_1's amex_metric: 0.796956
# [6500]	training's binary_logloss: 0.153845	training's amex_metric: 0.908376	valid_1's binary_logloss: 0.213593	valid_1's amex_metric: 0.796638
# [7000]	training's binary_logloss: 0.148703	training's amex_metric: 0.916486	valid_1's binary_logloss: 0.213387	valid_1's amex_metric: 0.79677
# [7500]	training's binary_logloss: 0.143847	training's amex_metric: 0.924523	valid_1's binary_logloss: 0.213216	valid_1's amex_metric: 0.797081
# [8000]	training's binary_logloss: 0.13951	training's amex_metric: 0.93161	valid_1's binary_logloss: 0.213072	valid_1's amex_metric: 0.796856
# [8500]	training's binary_logloss: 0.135761	training's amex_metric: 0.937622	valid_1's binary_logloss: 0.213038	valid_1's amex_metric: 0.796868
# [9000]	training's binary_logloss: 0.131602	training's amex_metric: 0.943508	valid_1's binary_logloss: 0.212957	valid_1's amex_metric: 0.797376
# [9500]	training's binary_logloss: 0.127869	training's amex_metric: 0.949195	valid_1's binary_logloss: 0.212948	valid_1's amex_metric: 0.797041
# [10000]	training's binary_logloss: 0.124201	training's amex_metric: 0.954397	valid_1's binary_logloss: 0.212876	valid_1's amex_metric: 0.797696
# [10500]	training's binary_logloss: 0.121002	training's amex_metric: 0.958877	valid_1's binary_logloss: 0.212866	valid_1's amex_metric: 0.797078
# Our fold 2 CV score is 0.797077570680373
#
# --------------------------------------------------
# Training fold 3 with 1365 features...
# [500]	training's binary_logloss: 0.33471	training's amex_metric: 0.781637	valid_1's binary_logloss: 0.337978	valid_1's amex_metric: 0.770447
# [1000]	training's binary_logloss: 0.243261	training's amex_metric: 0.798767	valid_1's binary_logloss: 0.250739	valid_1's amex_metric: 0.78102
# [1500]	training's binary_logloss: 0.218827	training's amex_metric: 0.812723	valid_1's binary_logloss: 0.230521	valid_1's amex_metric: 0.787348
# [2000]	training's binary_logloss: 0.205126	training's amex_metric: 0.82572	valid_1's binary_logloss: 0.222072	valid_1's amex_metric: 0.79087
# [2500]	training's binary_logloss: 0.198155	training's amex_metric: 0.835904	valid_1's binary_logloss: 0.219425	valid_1's amex_metric: 0.793635
# [3000]	training's binary_logloss: 0.191098	training's amex_metric: 0.845532	valid_1's binary_logloss: 0.217323	valid_1's amex_metric: 0.794455
# [3500]	training's binary_logloss: 0.184617	training's amex_metric: 0.856346	valid_1's binary_logloss: 0.216005	valid_1's amex_metric: 0.795989
# [4000]	training's binary_logloss: 0.178836	training's amex_metric: 0.866657	valid_1's binary_logloss: 0.215133	valid_1's amex_metric: 0.79673
# [4500]	training's binary_logloss: 0.173142	training's amex_metric: 0.876171	valid_1's binary_logloss: 0.214496	valid_1's amex_metric: 0.79749
# [5000]	training's binary_logloss: 0.167612	training's amex_metric: 0.885481	valid_1's binary_logloss: 0.214001	valid_1's amex_metric: 0.798056
# [5500]	training's binary_logloss: 0.162644	training's amex_metric: 0.893512	valid_1's binary_logloss: 0.213673	valid_1's amex_metric: 0.798499
# [6000]	training's binary_logloss: 0.158381	training's amex_metric: 0.901649	valid_1's binary_logloss: 0.213478	valid_1's amex_metric: 0.798894
# [6500]	training's binary_logloss: 0.15392	training's amex_metric: 0.908707	valid_1's binary_logloss: 0.213267	valid_1's amex_metric: 0.798843
# [7000]	training's binary_logloss: 0.148783	training's amex_metric: 0.916912	valid_1's binary_logloss: 0.213082	valid_1's amex_metric: 0.798814
# [7500]	training's binary_logloss: 0.143882	training's amex_metric: 0.924941	valid_1's binary_logloss: 0.212932	valid_1's amex_metric: 0.798925
# [8000]	training's binary_logloss: 0.139551	training's amex_metric: 0.931975	valid_1's binary_logloss: 0.212828	valid_1's amex_metric: 0.798774
# [8500]	training's binary_logloss: 0.13579	training's amex_metric: 0.937953	valid_1's binary_logloss: 0.212796	valid_1's amex_metric: 0.798605
# [9000]	training's binary_logloss: 0.131596	training's amex_metric: 0.9439	valid_1's binary_logloss: 0.212735	valid_1's amex_metric: 0.799296
# [9500]	training's binary_logloss: 0.127854	training's amex_metric: 0.949569	valid_1's binary_logloss: 0.212694	valid_1's amex_metric: 0.799534
# [10000]	training's binary_logloss: 0.124203	training's amex_metric: 0.955009	valid_1's binary_logloss: 0.212664	valid_1's amex_metric: 0.799075
# [10500]	training's binary_logloss: 0.120998	training's amex_metric: 0.959591	valid_1's binary_logloss: 0.212663	valid_1's amex_metric: 0.798498
# Our fold 3 CV score is 0.7984980026084305
#
# --------------------------------------------------
# Training fold 4 with 1365 features...
# [500]	training's binary_logloss: 0.334608	training's amex_metric: 0.782023	valid_1's binary_logloss: 0.338048	valid_1's amex_metric: 0.767819
# [1000]	training's binary_logloss: 0.243085	training's amex_metric: 0.799173	valid_1's binary_logloss: 0.250786	valid_1's amex_metric: 0.779326
# [1500]	training's binary_logloss: 0.218804	training's amex_metric: 0.813685	valid_1's binary_logloss: 0.230647	valid_1's amex_metric: 0.785154
# [2000]	training's binary_logloss: 0.205169	training's amex_metric: 0.826048	valid_1's binary_logloss: 0.22202	valid_1's amex_metric: 0.789986
# [2500]	training's binary_logloss: 0.198139	training's amex_metric: 0.836263	valid_1's binary_logloss: 0.219326	valid_1's amex_metric: 0.791191
# [3000]	training's binary_logloss: 0.191115	training's amex_metric: 0.845843	valid_1's binary_logloss: 0.217116	valid_1's amex_metric: 0.793105
# [3500]	training's binary_logloss: 0.184595	training's amex_metric: 0.856296	valid_1's binary_logloss: 0.215767	valid_1's amex_metric: 0.794202
# [4000]	training's binary_logloss: 0.178788	training's amex_metric: 0.866634	valid_1's binary_logloss: 0.214926	valid_1's amex_metric: 0.795121
# [4500]	training's binary_logloss: 0.173163	training's amex_metric: 0.875818	valid_1's binary_logloss: 0.2143	valid_1's amex_metric: 0.795579
# [5000]	training's binary_logloss: 0.167594	training's amex_metric: 0.884956	valid_1's binary_logloss: 0.213731	valid_1's amex_metric: 0.796884
# [5500]	training's binary_logloss: 0.16266	training's amex_metric: 0.893769	valid_1's binary_logloss: 0.213339	valid_1's amex_metric: 0.797366
# [6000]	training's binary_logloss: 0.158395	training's amex_metric: 0.901775	valid_1's binary_logloss: 0.213162	valid_1's amex_metric: 0.797464
# [6500]	training's binary_logloss: 0.153918	training's amex_metric: 0.908634	valid_1's binary_logloss: 0.213011	valid_1's amex_metric: 0.797429
# [7000]	training's binary_logloss: 0.148771	training's amex_metric: 0.916499	valid_1's binary_logloss: 0.212778	valid_1's amex_metric: 0.797752
# [7500]	training's binary_logloss: 0.143911	training's amex_metric: 0.924363	valid_1's binary_logloss: 0.212644	valid_1's amex_metric: 0.79793
# [8000]	training's binary_logloss: 0.139575	training's amex_metric: 0.931599	valid_1's binary_logloss: 0.212569	valid_1's amex_metric: 0.798014
# [8500]	training's binary_logloss: 0.135841	training's amex_metric: 0.937905	valid_1's binary_logloss: 0.212511	valid_1's amex_metric: 0.798433
# [9000]	training's binary_logloss: 0.131651	training's amex_metric: 0.943896	valid_1's binary_logloss: 0.212476	valid_1's amex_metric: 0.798056
# [9500]	training's binary_logloss: 0.127907	training's amex_metric: 0.949511	valid_1's binary_logloss: 0.212446	valid_1's amex_metric: 0.797685
# [10000]	training's binary_logloss: 0.124237	training's amex_metric: 0.954621	valid_1's binary_logloss: 0.212418	valid_1's amex_metric: 0.797923
# [10500]	training's binary_logloss: 0.121046	training's amex_metric: 0.958862	valid_1's binary_logloss: 0.21239	valid_1's amex_metric: 0.797756
# Our fold 4 CV score is 0.7977557163948712
# Our out of folds CV score is 0.7969998140385135
#   0%|          | 0/9 [00:00<?, ?it/s]
#
# --------------------------------------------------
# Training fold 0 with 1365 features...
# [500]	training's binary_logloss: 0.318219	training's amex_metric: 0.784031	valid_1's binary_logloss: 0.320575	valid_1's amex_metric: 0.770503
# [1000]	training's binary_logloss: 0.245054	training's amex_metric: 0.798484	valid_1's binary_logloss: 0.250582	valid_1's amex_metric: 0.778878
# [1500]	training's binary_logloss: 0.217977	training's amex_metric: 0.813146	valid_1's binary_logloss: 0.227728	valid_1's amex_metric: 0.786322
# [2000]	training's binary_logloss: 0.207193	training's amex_metric: 0.824684	valid_1's binary_logloss: 0.221165	valid_1's amex_metric: 0.789853
# [2500]	training's binary_logloss: 0.19875	training's amex_metric: 0.835506	valid_1's binary_logloss: 0.217534	valid_1's amex_metric: 0.792811
# [3000]	training's binary_logloss: 0.192356	training's amex_metric: 0.845536	valid_1's binary_logloss: 0.215664	valid_1's amex_metric: 0.794681
# [3500]	training's binary_logloss: 0.185584	training's amex_metric: 0.855127	valid_1's binary_logloss: 0.214004	valid_1's amex_metric: 0.795135
# [4000]	training's binary_logloss: 0.179654	training's amex_metric: 0.8651	valid_1's binary_logloss: 0.213078	valid_1's amex_metric: 0.795739
# [4500]	training's binary_logloss: 0.174033	training's amex_metric: 0.874807	valid_1's binary_logloss: 0.212401	valid_1's amex_metric: 0.796616
# [5000]	training's binary_logloss: 0.169037	training's amex_metric: 0.883826	valid_1's binary_logloss: 0.211987	valid_1's amex_metric: 0.7976
# [5500]	training's binary_logloss: 0.163675	training's amex_metric: 0.89238	valid_1's binary_logloss: 0.211489	valid_1's amex_metric: 0.79811
# [6000]	training's binary_logloss: 0.158896	training's amex_metric: 0.901135	valid_1's binary_logloss: 0.211246	valid_1's amex_metric: 0.798119
# [6500]	training's binary_logloss: 0.154889	training's amex_metric: 0.908256	valid_1's binary_logloss: 0.211099	valid_1's amex_metric: 0.79822
# [7000]	training's binary_logloss: 0.15079	training's amex_metric: 0.915119	valid_1's binary_logloss: 0.210994	valid_1's amex_metric: 0.797774
# [7500]	training's binary_logloss: 0.146541	training's amex_metric: 0.921489	valid_1's binary_logloss: 0.210824	valid_1's amex_metric: 0.797664
# [8000]	training's binary_logloss: 0.142091	training's amex_metric: 0.928502	valid_1's binary_logloss: 0.210693	valid_1's amex_metric: 0.798404
# [8500]	training's binary_logloss: 0.137772	training's amex_metric: 0.934644	valid_1's binary_logloss: 0.210574	valid_1's amex_metric: 0.797354
# [9000]	training's binary_logloss: 0.13407	training's amex_metric: 0.940688	valid_1's binary_logloss: 0.210531	valid_1's amex_metric: 0.797765
# [9500]	training's binary_logloss: 0.130589	training's amex_metric: 0.9462	valid_1's binary_logloss: 0.210488	valid_1's amex_metric: 0.797013
# [10000]	training's binary_logloss: 0.126748	training's amex_metric: 0.951574	valid_1's binary_logloss: 0.210421	valid_1's amex_metric: 0.798211
# [10500]	training's binary_logloss: 0.123108	training's amex_metric: 0.956707	valid_1's binary_logloss: 0.21034	valid_1's amex_metric: 0.797927
# Our fold 0 CV score is 0.797926878729277
#
# --------------------------------------------------
# Training fold 1 with 1365 features...
# [500]	training's binary_logloss: 0.317398	training's amex_metric: 0.78413	valid_1's binary_logloss: 0.32265	valid_1's amex_metric: 0.767438
# [1000]	training's binary_logloss: 0.244202	training's amex_metric: 0.798716	valid_1's binary_logloss: 0.253522	valid_1's amex_metric: 0.77914
# [1500]	training's binary_logloss: 0.217156	training's amex_metric: 0.813101	valid_1's binary_logloss: 0.231079	valid_1's amex_metric: 0.784185
# [2000]	training's binary_logloss: 0.206319	training's amex_metric: 0.824755	valid_1's binary_logloss: 0.224401	valid_1's amex_metric: 0.788699
# [2500]	training's binary_logloss: 0.197959	training's amex_metric: 0.835937	valid_1's binary_logloss: 0.220731	valid_1's amex_metric: 0.792478
# [3000]	training's binary_logloss: 0.191658	training's amex_metric: 0.845172	valid_1's binary_logloss: 0.218823	valid_1's amex_metric: 0.794444
# [3500]	training's binary_logloss: 0.184909	training's amex_metric: 0.855318	valid_1's binary_logloss: 0.217181	valid_1's amex_metric: 0.79485
# [4000]	training's binary_logloss: 0.178985	training's amex_metric: 0.865048	valid_1's binary_logloss: 0.216217	valid_1's amex_metric: 0.795896
# [4500]	training's binary_logloss: 0.17339	training's amex_metric: 0.874777	valid_1's binary_logloss: 0.215602	valid_1's amex_metric: 0.795829
# [5000]	training's binary_logloss: 0.168409	training's amex_metric: 0.883539	valid_1's binary_logloss: 0.215203	valid_1's amex_metric: 0.795419
# [5500]	training's binary_logloss: 0.163104	training's amex_metric: 0.892336	valid_1's binary_logloss: 0.21474	valid_1's amex_metric: 0.795541
# [6000]	training's binary_logloss: 0.15831	training's amex_metric: 0.900535	valid_1's binary_logloss: 0.214461	valid_1's amex_metric: 0.796068
# [6500]	training's binary_logloss: 0.154347	training's amex_metric: 0.907802	valid_1's binary_logloss: 0.214252	valid_1's amex_metric: 0.796915
# [7000]	training's binary_logloss: 0.150274	training's amex_metric: 0.914839	valid_1's binary_logloss: 0.214135	valid_1's amex_metric: 0.79689
# [7500]	training's binary_logloss: 0.146006	training's amex_metric: 0.921434	valid_1's binary_logloss: 0.213901	valid_1's amex_metric: 0.797019
# [8000]	training's binary_logloss: 0.141521	training's amex_metric: 0.928377	valid_1's binary_logloss: 0.213758	valid_1's amex_metric: 0.796277
# [8500]	training's binary_logloss: 0.137216	training's amex_metric: 0.93502	valid_1's binary_logloss: 0.21371	valid_1's amex_metric: 0.796844
# [9000]	training's binary_logloss: 0.133521	training's amex_metric: 0.941187	valid_1's binary_logloss: 0.213597	valid_1's amex_metric: 0.797149
# [9500]	training's binary_logloss: 0.13006	training's amex_metric: 0.946162	valid_1's binary_logloss: 0.213567	valid_1's amex_metric: 0.79796
# [10000]	training's binary_logloss: 0.12623	training's amex_metric: 0.951765	valid_1's binary_logloss: 0.213642	valid_1's amex_metric: 0.797439
# [10500]	training's binary_logloss: 0.122584	training's amex_metric: 0.956788	valid_1's binary_logloss: 0.213664	valid_1's amex_metric: 0.796591
# Our fold 1 CV score is 0.7965906123357211
#
# --------------------------------------------------
# Training fold 2 with 1365 features...
# [500]	training's binary_logloss: 0.317416	training's amex_metric: 0.785196	valid_1's binary_logloss: 0.322437	valid_1's amex_metric: 0.767522
# [1000]	training's binary_logloss: 0.243985	training's amex_metric: 0.799808	valid_1's binary_logloss: 0.253576	valid_1's amex_metric: 0.776565
# [1500]	training's binary_logloss: 0.216892	training's amex_metric: 0.81409	valid_1's binary_logloss: 0.231493	valid_1's amex_metric: 0.783845
# [2000]	training's binary_logloss: 0.205941	training's amex_metric: 0.82581	valid_1's binary_logloss: 0.225192	valid_1's amex_metric: 0.786806
# [2500]	training's binary_logloss: 0.19752	training's amex_metric: 0.836359	valid_1's binary_logloss: 0.22173	valid_1's amex_metric: 0.789154
# [3000]	training's binary_logloss: 0.19118	training's amex_metric: 0.846173	valid_1's binary_logloss: 0.220021	valid_1's amex_metric: 0.79015
# [3500]	training's binary_logloss: 0.184421	training's amex_metric: 0.855749	valid_1's binary_logloss: 0.21854	valid_1's amex_metric: 0.791546

# %% [markdown]
# # Blend

# %%
seeds = [42, 1192, 2022]

pred = 0.0
for i,seed in enumerate(seeds):
    if i==0:
        blend = pd.read_csv(OUTPUT_DIR / f'test_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{seed}_adv{THRES}.csv')
        #blend['prediction'] /= len(seeds)
        pred = blend['prediction'].values / len(seeds)
    else:
        tmp = pd.read_csv(OUTPUT_DIR / f'test_lgbm_{CFG.boosting_type}_baseline_{CFG.n_folds}fold_seed{seed}_adv{THRES}.csv', usecols=['prediction'])
        pred += tmp['prediction'].values / len(seeds)
        #pred /= len(seeds)
        #blend['prediction'] = blend['prediction'] + pred
        del tmp
        gc.collect()
blend['prediction'] = pred


blend.to_csv(OUTPUT_DIR / f'test_lgbm_baseline_5fold_seed_blend_adv{THRES}.csv', index=False)

# %%
# Submit blend.csv to Kaggle dataset

# %% [markdown]
# # Read Submission File
# This is the submission file corresponding to the output of the previous pipeline (using the average blend of 3 seeds)

# %%
# sub = pd.read_csv('../input/amex-sub/test_lgbm_baseline_5fold_seed_blend.csv')
# sub.to_csv('test_lgbm_baseline_5fold_seed_blend.csv', index = False)
